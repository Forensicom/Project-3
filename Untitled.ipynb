# %%
import yfinance as yf

min_date = "2023-07-21"
max_date = "2023-07-31"
bitcoin = yf.Ticker("BTC-USD")
ethereum = yf.Ticker("ETH-USD")
tether = yf.Ticker("USDT-USD")
ripple = yf.Ticker("XRP-USD")
binance = yf.Ticker("BNB-USD")

# bitcoin.history(period="1mo")
bitcoin.history(start = min_date, end=max_date)
drop columns - Dividends stock pslits

convert to df
# Out:
#                                    Open          High           Low  \
# Date
# 2023-07-21 00:00:00+00:00  29805.111328  30045.998047  29733.851562
# 2023-07-22 00:00:00+00:00  29908.697266  29991.615234  29664.121094
# 2023-07-23 00:00:00+00:00  29790.111328  30330.640625  29741.527344
# 2023-07-24 00:00:00+00:00  30081.662109  30093.394531  28934.294922
# 2023-07-25 00:00:00+00:00  29178.970703  29353.160156  29062.433594
# 2023-07-26 00:00:00+00:00  29225.759766  29675.552734  29113.912109
# 2023-07-27 00:00:00+00:00  29353.798828  29560.966797  29099.351562
# 2023-07-28 00:00:00+00:00  29212.164062  29521.513672  29125.845703
# 2023-07-29 00:00:00+00:00  29319.445312  29396.843750  29264.166016
# 2023-07-30 00:00:00+00:00  29357.093750  29443.169922  29059.501953
#
#                                   Close       Volume  Dividends  Stock Splits
# Date
# 2023-07-21 00:00:00+00:00  29908.744141  10972789818        0.0           0.0
# ...
